# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
#import cartopy.feature as cfeature
#import cartopy.crs as ccrs

# %%
data = xr.open_dataset('/ec/res4/scratch/itas/ece4/lf01/domain_cfg.nc')

# %%
var = 'bathy_metry'
plt.figure(figsize=(10, 6))
#plt.title(f'Bathymetry [{var}] ')
plt.contourf(data[var][0,:,:])
plt.colorbar()
plt.show()
