# %%
import numpy as np
import subprocess
import os
import glob
import yaml
import xarray as xr
import matplotlib.pyplot as plt
import goat_plots as gp
import goat_io as io
import goat_tools as gt
import goat_means as gm

# %%
gp.plot_ts_ma3d('alef', 1990, 2199, 'to')
gp.plot_ts_ma3d('chet', 1990, 2199, 'to')
plt.xlabel("Years")
plt.ylabel("Global Mean Temperature")
plt.gca().legend(('alef','chet'))

# %%
gp.plot_ts_ma3d('alef', 1990, 2035, 'to')
gp.plot_ts_ma3d('beth', 1990, 2035, 'to')
gp.plot_ts_ma3d('giml', 1990, 2035, 'to')
gp.plot_ts_ma3d('dalt', 1990, 2035, 'to')
plt.xlabel("Years")
plt.ylabel("Global Mean Temperature")
plt.gca().legend(('alef','beth','gimel','dalet'))

# %%
gp.plot_ts_ma2d('alef', 1990, 2035, 'tos')
gp.plot_ts_ma2d('beth', 1990, 2035, 'tos')
gp.plot_ts_ma2d('giml', 1990, 2035, 'tos')
gp.plot_ts_ma2d('dalt', 1990, 2035, 'tos')
plt.xlabel("Years")
plt.ylabel("Mean Surface Temperature")
plt.gca().legend(('alef','beth','gimel','dalet'))

# %%
gp.plot_ts_ma2d('alef', 1990, 2200, 'tos')

# %%
gp.plot_ts_ma3d('alef', 1990, 2200, 'to')

# %%
gp.plot_ts_ma3d('alfa', 1990, 2100, 'to')
plt.xlabel("Years")
plt.ylabel("Global Mean Temperature")
plt.gca().legend(('alfa'))

# %%
gp.plot_ts_ma3d('alfa', 1990, 2100, 'to')
gp.plot_ts_ma3d('alef', 1990, 2100, 'to')
gp.plot_ts_ma3d('chet', 1990, 2100, 'to')
plt.xlabel("Years")
plt.ylabel("Global Mean Temperature")
plt.gca().legend(('alfa','alef','chet'))

# %%
gp.map2d('alef', 2100, 1, 'tos', 0, 35)

# %%
gp.map2d('alfa', 2100, 1, 'tos', 0, 35)

# %%
gp.plot_ts_ma2d('alfa', 1990, 2100, 'tos')
gp.plot_ts_ma2d('alef', 1990, 2100, 'tos')
gp.plot_ts_ma2d('chet', 1990, 2100, 'tos')
plt.xlabel("Years")
plt.ylabel("Mean Surface Temperature")
plt.gca().legend(('alfa','alef','chet'))

# %%
gp.gregory_plot_ma3d('alef', 1990, 2050, 'to', 'qt_oce')

# %%
gp.gregory_plot_ma3d('alef', 1990, 2035, 'to', 'qt_oce')
gp.gregory_plot_ma3d('beth', 1990, 2035, 'to', 'qt_oce')
gp.gregory_plot_ma3d('giml', 1990, 2035, 'to', 'qt_oce')
gp.gregory_plot_ma3d('dalt', 1990, 2035, 'to', 'qt_oce')
plt.xlabel("Mean Global Temperature")
plt.ylabel("Net Solar Radiation Flux")
plt.gca().legend(('alef','beth','gimel','dalet'))

# %%
gp.gregory_plot_ma3d('alfa', 1990, 2100, 'to', 'qt_oce')
gp.gregory_plot_ma3d('alef', 1990, 2100, 'to', 'qt_oce')
gp.gregory_plot_ma3d('chet', 1990, 2100, 'to', 'qt_oce')
plt.xlabel("Mean Global Temperature")
plt.ylabel("Net Solar Radiation Flux")
plt.gca().legend(('alfa','alef','chet'))

# %%
ave = gm.ave_T('alef', 1990, 'to')

# %%
ave0 = gm.ave_T_sub('alef', 1990, 'to', 0, 9)
ave1 = gm.ave_T_sub('alef', 1990, 'to', 10, 20)
ave2 = gm.ave_T_sub('alef', 1990, 'to', 21, 30)
gp.plot_ts_ma3d_sub('alef', 1990, 2040, 'to', 0, 9, ave0)
gp.plot_ts_ma3d_sub('alef', 1990, 2040, 'to', 10, 20, ave1)
gp.plot_ts_ma3d_sub('alef', 1990, 2040, 'to', 21, 30, ave2)
plt.ylabel("Temperature")
plt.xlabel("Years")
plt.gca().legend(('mixed layer','pycnocline','deep waters'))

# %%
gp.plot_ts_ma3d_sub('alef', 1990, 2040, 'to', 21, 30, 1)
gp.plot_ts_ma3d_sub('giml', 1990, 2040, 'to', 21, 30, 1)
gp.plot_ts_ma3d_sub('dalt', 1990, 2040, 'to', 21, 30, 1)
plt.ylabel("Abyssal Temperature")
plt.xlabel("Years")
plt.gca().legend(('alef','giml','dalt'))

# %%
gp.plot_ts_ma3d_sub('alef', 1990, 2040, 'to', 10, 20, 1)
gp.plot_ts_ma3d_sub('giml', 1990, 2040, 'to', 10, 20, 1)
gp.plot_ts_ma3d_sub('dalt', 1990, 2040, 'to', 10, 20, 1)
plt.ylabel("Pycnocline Temperature")
plt.xlabel("Years")
plt.gca().legend(('alef','giml','dalt'))

# %%
gp.plot_ts_ma3d_sub('alef', 1990, 2040, 'to', 0, 9, 1)
gp.plot_ts_ma3d_sub('giml', 1990, 2040, 'to', 0, 9, 1)
gp.plot_ts_ma3d_sub('dalt', 1990, 2040, 'to', 0, 9, 1)
plt.ylabel("Surface Temperature")
plt.xlabel("Years")
plt.gca().legend(('alef','giml','dalt'))

# %%
gp.plot_hovmoller('alef', 2050, 2100, 'to')

# %%
gp.plot_hovmoller('alef', 1990, 2100, 'so')

# %%
gp.plot_prof('alef', 1990, 2000, 'to')

# %%
gp.plot_ts_ma3d('alef', 1990, 2050, 'to')
gp.plot_ts_ra3d('alef', 1990, 2050, 'to')

# %%
data = io.readmf_ice('alef', 1990, 2100)
df = gm.elements('alef')
tt = gt.dateDecimal(data['time'].values)
vv = gm.movave(data['qt_oce_ai'].weighted(df['area']).mean(dim=['y', 'x']).values.flatten(),12)
plt.plot(tt,vv)

# %%
data = io.readmf_T('alef', 1990, 2100)
df = gm.elements('alef')
tt = gt.dateDecimal(data['time'].values)
vv = gm.movave(data['qt_oce'].weighted(df['dx']).mean(dim=['x']).values.flatten(),12)
plt.plot(tt,vv)

# %%
data = io.readmf_T('alef', 1990, 2100)
df = gm.elements('alef')
hovm = data['heatc'].weighted(df['dx']).mean(dim=['x'])    
hovm.plot(x='time', y='y')
