# %%
import numpy as np
import subprocess
import os
import glob
import yaml
import xarray as xr
import netCDF4
import math
import matplotlib.pyplot as plt
import goat_plots as gp
import goat_io as io
import goat_tools as gt
import goat_means as gm
import goat_graphs as gg

# %%
expname='half'
rdata = io.readmf_T(expname, 2250, 2300)
df = gm.elements(expname='half') 
rdata['tos'].mean(dim=['time']).plot(vmin=-2,vmax=30, cmap=plt.cm.coolwarm)
plt.title('half')
# Out:
# Text(0.5, 1.0, 'half')

# %%
rdata = io.readmf_T('lfr0', 2250, 2300)
df = gm.elements(expname='lfr0') 
rdata['tos'].mean(dim=['time']).plot(vmin=-2,vmax=30, cmap=plt.cm.coolwarm)
plt.title('ref')
# Out:
# Text(0.5, 1.0, 'ref')

# %%
gg.gregoryplot('mesh', 2100, 2200, 'thetao', '3D', 'qt_oce', '2D', 'mave')
# Out:
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...

# %%
gg.gregoryplot('half', 1990, 2100, 'thetao', '3D', 'qt_oce', '2D', 'mave')
# Out:
#  Averaged data found
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...

# %%
gg.gregoryplot('lfr0', 1990, 2100, 'thetao', '3D', 'qt_oce', '2D', 'mave')
# Out:
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
gg.timeseries('half', 1990, 2100, 'thetao', '2D', 1, 'norm', 'ave', 0)
gg.timeseries('half', 1990, 2100, 'thetao', '2D', 1, 'norm', 'mave', 0)
gg.timeseries('lfr0', 1990, 2100, 'tos', '2D', 1, 'norm', 'ave', 0)
gg.timeseries('lfr0', 1990, 2100, 'tos', '2D', 1, 'norm', 'mave', 0)
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...
#  Averaged data found

# %%
gg.timeseries('mesh', 1990, 2200, 'thetao', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('mesh', 1990, 2200, 'thetao', '3D', 1, 'norm', 'mave', 0)
# Out:
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...
#  Averaged data found

# %%
#gg.gregoryplot('lf00', 1990, 2030, 'thetao', '3D', 'qt_oce', '2D', 'ave')
gg.gregoryplot('lf00', 2000, 2030, 'thetao', '3D', 'qt_oce', '2D', 'mave')
# Out:
#  Averaged data found
#  Averaged data found

# %%
gg.timeseries('lf01', 1990, 2090, 'sbt', '2D', 1, 'norm', 'ave', 0)
gg.timeseries('lf01', 1990, 2090, 'sbt', '2D', 1, 'norm', 'mave', 0)
gg.timeseries('lfr0', 1990, 2400, 'sbt', '2D', 1, 'norm', 'ave', 0)
gg.timeseries('lfr0', 1990, 2400, 'sbt', '2D', 1, 'norm', 'mave', 0)
gg.timeseries('lfr1', 1990, 2390, 'sbt', '2D', 1, 'norm', 'ave', 400)
gg.timeseries('lfr1', 1990, 2390, 'sbt', '2D', 1, 'norm', 'mave', 400)
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found

# %%
#gg.timeseries('fx00', 1990, 2100, 'thetao', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('half', 1990, 2100, 'thetao', '3D', 1, 'norm', 'ave', 0)
#gg.timeseries('fx00', 1990, 2100, 'thetao', '3D', 1, 'norm', 'mave', 0)
gg.timeseries('half', 1990, 2100, 'thetao', '3D', 1, 'norm', 'mave', 0)
plt.ylabel("Global mean temperature")
plt.title("Trials with new ORCA2 domain_cfg")
plt.gca().legend(('half - mean','half - moving mean'))
# Out:
#  Averaged data found
#  Averaged data found
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
gg.timeseries('fx04', 1990, 2020, 'thetao', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('tide', 1990, 2020, 'thetao', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('wght', 1990, 2020, 'thetao', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('mesh', 1990, 2020, 'thetao', '3D', 1, 'norm', 'ave', 0)
plt.ylabel("Global mean temperature")
plt.title("Effect of tidal mixing by internal waves (IWM)")
plt.gca().legend(('fx04 - no IWM','tide - with IWM','wght - new weights','mesh - new domain'))
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...

# %%
gg.timeseries('fx04', 1990, 2100, 'thetao', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('tide', 1990, 2100, 'thetao', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('wght', 1990, 2100, 'thetao', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('mesh', 1990, 2100, 'thetao', '3D', 1, 'norm', 'ave', 0)
plt.ylabel("Global mean temperature")
plt.title("Trials with tidal mixing (IWM), new weights and new ORCA2 domain_cfg")
plt.gca().legend(('fx04 - no IWM','tide - with IWM','wght - new weights','mesh - new domain_cfg'))
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found

# %%
gg.timeseries('fx04', 1990, 2100, 'thetao', '3D', 1, 'norm', 'mave', 0)
gg.timeseries('tide', 1990, 2100, 'thetao', '3D', 1, 'norm', 'mave', 0)
gg.timeseries('wght', 1990, 2100, 'thetao', '3D', 1, 'norm', 'mave', 0)
gg.timeseries('mesh', 1990, 2100, 'thetao', '3D', 1, 'norm', 'mave', 0)
plt.ylabel("Global mean temperature")
plt.title("Trials with tidal mixing (IWM), new weights and new ORCA2 domain_cfg")
plt.gca().legend(('fx04 - no IWM','tide - with IWM','wght - new weights','mesh - new domain_cfg'))
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
gg.timeseries('fx04', 1990, 2020, 'tos', '2D', 1, 'norm', 'ave', 0)
gg.timeseries('tide', 1990, 2017, 'tos', '2D', 1, 'norm', 'ave', 0)
plt.xlim(1990,2020)
# Out:
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...
# (1990.0, 2020.0)

# %%
gg.timeseries('fx04', 1990, 2020, 'sbt', '2D', 1, 'norm', 'ave', 0)
gg.timeseries('tide', 1990, 2017, 'sbt', '2D', 1, 'norm', 'ave', 0)
plt.xlim(1990,2020)
# Out:
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...
# (1990.0, 2020.0)

# %%
gg.timeseries('fix0', 1990, 2422, 'thetao', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('fix1', 1990, 2400, 'thetao', '3D', 1, 'norm', 'ave', 432)
gg.timeseries('fix2', 1990, 2400, 'thetao', '3D', 1, 'norm', 'ave', 842)
plt.ylabel("Global mean temperature")
plt.gca().legend(('fix0','fix1','fix2'))
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found

# %%
gg.timeseries('fix0', 1990, 2422, 'tos', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('fix1', 1990, 2400, 'tos', '3D', 1, 'norm', 'ave', 432)
gg.timeseries('fix2', 1990, 2400, 'tos', '3D', 1, 'norm', 'ave', 842)
plt.gca().legend(('fix0','fix1','fix2'))
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found

# %%
gg.timeseries('fix0', 1990, 2422, 'sbt', '3D', 1, 'norm', 'ave', 0)
gg.timeseries('fix1', 1990, 2400, 'sbt', '3D', 1, 'norm', 'ave', 432)
gg.timeseries('fix2', 1990, 2400, 'sbt', '3D', 1, 'norm', 'ave', 842)
plt.gca().legend(('fix0','fix1','fix2'))
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found

# %%
gg.profile('fix0', 2300, 2320, 'thetao', 1, 'norm')
# Out:
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...

# %%
gg.hovmoller('fix0', 2050, 2400, 'thetao', 'time', 'z')
plt.title('fix0')
# Out:
#  Averaged data found
# Text(0.5, 1.0, 'fix0')

# %%
gg.hovmoller('fix1', 1990, 2400, 'thetao', 'time', 'z')
plt.title('fix1')
# Out:
#  Averaged data found
# Text(0.5, 1.0, 'fix1')

# %%
gg.hovmoller('fix2', 1990, 2400, 'thetao', 'time', 'z')
plt.title('fix2')
# Out:
#  Averaged data found
# Text(0.5, 1.0, 'fix2')

# %%
gg.hovmoller('fix3', 1990, 2014, 'thetao', 'time', 'z')
plt.title('fix3')
# Out:
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
#  Saving averaged data ...
# Text(0.5, 1.0, 'fix3')

# %%
gg.gregoryplot('fix0', 1990, 2422, 'thetao', '3D', 'qt_oce', '2D', 'mave')
gg.gregoryplot('fix1', 1990, 2400, 'thetao', '3D', 'qt_oce', '2D', 'mave')
gg.gregoryplot('fix2', 1990, 2400, 'thetao', '3D', 'qt_oce', '2D', 'mave')
plt.xlabel("Global Mean Temperature")
plt.gca().legend(('fix0','fix1','fix2'))
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found

# %%
ave0 = gm.ave_T_sub('fix0', 1990, 'thetao', 0, 9)
ave1 = gm.ave_T_sub('fix0', 1990, 'thetao', 10, 20)
ave2 = gm.ave_T_sub('fix0', 1990, 'thetao', 21, 30)
gg.timeseries('fix0', 1990, 2422, 'thetao-mix', '3D', ave0, 'norm', 'ave', 0)
gg.timeseries('fix0', 1990, 2400, 'thetao-pyc', '3D', ave1, 'norm', 'ave', 432)
gg.timeseries('fix0', 1990, 2400, 'thetao-aby', '3D', ave2, 'norm', 'ave', 842)
plt.xlabel("Years")
plt.ylabel("Normalized Global Temperature")
plt.gca().legend(('Surface','Pycnocline','Abyss'))
