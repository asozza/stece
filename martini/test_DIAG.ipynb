# %%
import os
import glob
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import goat_io as io
import goat_tools as gt
import goat_means as gm
import goat_graphs as gg

# %%
expname='lfr0'
startyear=1990
endyear=1991
dirs = io.folders(expname)
filename = os.path.join(dirs['exp'], 'domain_cfg.nc')
domain = xr.open_mfdataset(filename, preprocess=io.preproc_nemo_domain)
domain = domain.isel(time=0)
domain = domain.drop_vars({'time'})
domain
# Out:
# <xarray.Dataset> Size: 52MB
# Dimensions:        (y: 148, x: 180, z: 31)
# Dimensions without coordinates: y, x, z
# Data variables: (12/50)
#     nav_lon        (y, x) float32 107kB dask.array<chunksize=(148, 180), meta=np.ndarray>
#     nav_lat        (y, x) float32 107kB dask.array<chunksize=(148, 180), meta=np.ndarray>
#     nav_lev        (z) float32 124B dask.array<chunksize=(31,), meta=np.ndarray>
#     jpiglo         int32 4B ...
#     jpjglo         int32 4B ...
#     jpkglo         int32 4B ...
#     ...             ...
#     mask_csglo     (y, x) int32 107kB dask.array<chunksize=(148, 180), meta=np.ndarray>
#     mask_csemp     (y, x) int32 107kB dask.array<chunksize=(148, 180), meta=np.ndarray>
#     mask_csrnf     (y, x) int32 107kB dask.array<chunksize=(148, 180), meta=np.ndarray>
#     mask_csgrpglo  (y, x) int32 107kB dask.array<chunksize=(148, 180), meta=np.ndarray>
#     mask_csgrpemp  (y, x) int32 107kB dask.array<chunksize=(148, 180), meta=np.ndarray>
# ...

# %%
var='thetao'
ndim='3D'
gg.timeseries('lfr0', 1990, 2400, var, ndim, 1, 'norm', 'mave', 0, 'b')
gg.timeseries('lfr1', 1990, 2391, var, ndim, 1, 'norm', 'mave', 410, 'b')
gg.timeseries('lfr2', 1990, 2350, var, ndim, 1, 'norm', 'mave', 811, 'b')
gg.timeseries('lfr3', 1990, 2350, var, ndim, 1, 'norm', 'mave', 1171, 'b')
gg.timeseries('lfr4', 1990, 2350, var, ndim, 1, 'norm', 'mave', 1531, 'b')
gg.timeseries('lfr5', 1990, 2350, var, ndim, 1, 'norm', 'mave', 1891, 'b')
gg.timeseries('lfs1', 1990, 2350, var, ndim, 1, 'norm', 'mave', 2251, 'b')
gg.timeseries('lfs2', 1990, 2350, var, ndim, 1, 'norm', 'mave', 2611, 'b')
plt.xlim(4500,5000)
plt.ylim(3.5,4)
# Out:
#  Averaged data not found. Creating new file ...
#  Loading data ...
#  Averaging ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 var='thetao'
#       2 ndim='3D'
# ----> 3 gg.timeseries('lfr0', 1990, 2400, var, ndim, 1, 'norm', 'mave', 0, 'b')
#       4 gg.timeseries('lfr1', 1990, 2391, var, ndim, 1, 'norm', 'mave', 410, 'b')
#       5 gg.timeseries('lfr2', 1990, 2350, var, ndim, 1, 'norm', 'mave', 811, 'b')
#
# File /lus/h2resw01/hpcperm/itas/src/github/stece/goat/goat_graphs.py:33, in timeseries(expname, startyear, endyear, var, ndim, norm, idx_norm, idx_ave, offset, color)
#      30     isub = True
#      32 # read (or create) averaged data
# ---> 33 data = io.read_averaged_timeseries_T(expname, startyear, endyear, var, ndim, isub)
#      34 # assembly and plot
#      35 tt = data['time'].values.flatten()
#
# ...

# %%
var='tos'
ndim='2D'
gg.timeseries('lfr0', 1990, 2400, var, ndim, 1, 'norm', 'mave', 0, 'b')
gg.timeseries('lfr1', 1990, 2391, var, ndim, 1, 'norm', 'mave', 410, 'b')
gg.timeseries('lfr2', 1990, 2350, var, ndim, 1, 'norm', 'mave', 811, 'b')
gg.timeseries('lfr3', 1990, 2350, var, ndim, 1, 'norm', 'mave', 1171, 'b')
gg.timeseries('lfr4', 1990, 2350, var, ndim, 1, 'norm', 'mave', 1531, 'b')
gg.timeseries('lfr5', 1990, 2350, var, ndim, 1, 'norm', 'mave', 1891, 'b')
gg.timeseries('lfs1', 1990, 2350, var, ndim, 1, 'norm', 'mave', 2251, 'b')
gg.timeseries('lfs2', 1990, 2350, var, ndim, 1, 'norm', 'mave', 2611, 'b')
#plt.xlim(4500,5000)
#plt.ylim(16,17)
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found

# %%
var='sbt'
ndim='2D'
gg.timeseries('lfr0', 1990, 2400, var, ndim, 1, 'norm', 'mave', 0, 'b')
gg.timeseries('lfr1', 1990, 2391, var, ndim, 1, 'norm', 'mave', 410, 'b')
gg.timeseries('lfr2', 1990, 2350, var, ndim, 1, 'norm', 'mave', 811, 'b')
gg.timeseries('lfr3', 1990, 2350, var, ndim, 1, 'norm', 'mave', 1171, 'b')
gg.timeseries('lfr4', 1990, 2350, var, ndim, 1, 'norm', 'mave', 1531, 'b')
gg.timeseries('lfr5', 1990, 2350, var, ndim, 1, 'norm', 'mave', 1891, 'b')
gg.timeseries('lfs1', 1990, 2350, var, ndim, 1, 'norm', 'mave', 2251, 'b')
gg.timeseries('lfs2', 1990, 2350, var, ndim, 1, 'norm', 'mave', 2611, 'b')
#plt.xlim(4500,5000)
#plt.ylim(1.5,2.5)
# Out:
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found
#  Averaged data found

# %%
# gregory plot
var_x='thetao'
ndim_x='3D'
var_y='qt_oce'
ndim_y='2D'
idx_ave='ave'
gg.gregoryplot('lfr0', 1990, 2400, var_x, ndim_x, var_y, ndim_y, idx_ave)
gg.gregoryplot('lfr1', 1990, 2391, var_x, ndim_x, var_y, ndim_y, idx_ave)
gg.gregoryplot('lfr2', 1990, 2350, var_x, ndim_x, var_y, ndim_y, idx_ave)
gg.gregoryplot('lfr3', 1990, 2350, var_x, ndim_x, var_y, ndim_y, idx_ave)
gg.gregoryplot('lfr4', 1990, 2350, var_x, ndim_x, var_y, ndim_y, idx_ave)
gg.gregoryplot('lfr5', 1990, 2350, var_x, ndim_x, var_y, ndim_y, idx_ave)
gg.gregoryplot('lfs1', 1990, 2350, var_x, ndim_x, var_y, ndim_y, idx_ave)
gg.gregoryplot('lfs2', 1990, 2350, var_x, ndim_x, var_y, ndim_y, idx_ave)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 ndim_y='2D'
#       5 idx_ave='ave'
# ----> 6 gg.gregoryplot('lfr0', 1990, 2400, var_x, ndim_x, var_y, ndim_y, idx_ave)
#       7 gg.gregoryplot('lfr1', 1990, 2391, var_x, ndim_x, var_y, ndim_y, idx_ave)
#       8 gg.gregoryplot('lfr2', 1990, 2350, var_x, ndim_x, var_y, ndim_y, idx_ave)
#
# NameError: name 'gg' is not defined
