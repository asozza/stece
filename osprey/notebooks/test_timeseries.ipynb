# %%
import yaml
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from osprey.graphics.timeseries import timeseries, timeseries_two

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2060, varlabel='thetao', reader='post', metric='diff')
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='thetao', reader='post', metric='diff')
# Out:
# 2024-09-09 08:49:20,370 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_diff_1990-2060.nc
# 2024-09-09 08:49:20,437 - INFO - Averaged data found.
# 2024-09-09 08:49:20,460 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao_diff_1990-2059.nc
# 2024-09-09 08:49:20,465 - INFO - Averaged data found.

# %%
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='tos', color='red', rescaled=True, reader='post')
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='thetao-pyc', color='green', rescaled=True, reader='post')
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='sbt', color='blue', rescaled=True, reader='post')
plt.gca().legend(['surface','pycnocline','bottom'])
# Out:
# 2024-09-09 08:49:38,765 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_tos_base_1990-2059.nc
# 2024-09-09 08:49:38,783 - INFO - Averaged data found.
# 2024-09-09 08:49:38,793 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao-pyc_base_1990-2059.nc
# 2024-09-09 08:49:39,057 - INFO - Averaged data found.
# 2024-09-09 08:49:39,060 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_sbt_base_1990-2059.nc
# 2024-09-09 08:49:39,207 - INFO - Averaged data found.

# %%
timeseries_two(expname1='lfr0',expname2='FE01', startyear=1990, endyear=2059, varlabel='thetao', reader='post', metric='diff')
# Out:
# 2024-09-09 09:19:43,597 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_base_1990-2059.nc
# 2024-09-09 09:19:43,771 - INFO - Averaged data found.
# 2024-09-09 09:19:43,772 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao_base_1990-2059.nc
# 2024-09-09 09:19:43,778 - INFO - Averaged data found.
