# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from osprey.graphics.timeseries import timeseries, timeseries_two

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='diff', rescale=True, color='lightcoral', linestyle='--', label='diff - REF')
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='reldiff', rescale=True, color='bisque', linestyle='--', label='reldiff - REF')
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='abs', rescale=True, color='khaki', linestyle='--', label='abs - REF')
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='relabs', rescale=True, color='darkseagreen', linestyle='--', label='relabs - REF')
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='sqerr', rescale=True, color='cornflowerblue', linestyle='--', label='sqerr - REF')
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='relsqerr', rescale=True, color='thistle', linestyle='--', label='relsqerr - REF')
#
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='diff', rescale=True, color='red', linestyle='-', label='diff - EOF')
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='reldiff', rescale=True, color='orange', linestyle='-', label='reldiff - EOF')
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='abs', rescale=True, color='brown', linestyle='-', label='abs - EOF')
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='relabs', rescale=True, color='green', linestyle='-', label='relabs - EOF')
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='sqerr', rescale=True, color='blue', linestyle='-', label='sqerr - EOF')
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='relsqerr', rescale=True, color='purple', linestyle='-', label='relsqerr - EOF')
plt.legend(
    bbox_to_anchor=(1.05, 1),  # x, y coordinates for legend placement
    loc='upper left',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.ylabel('C(t)/C(0) []')
plt.xlabel('t [years]')
plt.title("Cost functions of global mean temperature \n with respect to the equilibrium state [2390-2400]")
# Out:
# 2024-09-18 14:20:09,874 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_diff_1990-2079.nc
# 2024-09-18 14:20:09,878 - INFO - Averaged data found.
# 2024-09-18 14:20:09,886 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_reldiff_1990-2079.nc
# 2024-09-18 14:20:09,890 - INFO - Averaged data found.
# 2024-09-18 14:20:09,892 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_abs_1990-2079.nc
# 2024-09-18 14:20:09,895 - INFO - Averaged data found.
# 2024-09-18 14:20:09,897 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_relabs_1990-2079.nc
# 2024-09-18 14:20:09,901 - INFO - Averaged data found.
# 2024-09-18 14:20:09,903 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_sqerr_1990-2079.nc
# 2024-09-18 14:20:09,906 - INFO - Averaged data found.
# 2024-09-18 14:20:09,908 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_relsqerr_1990-2079.nc
# ...

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='diff', rescale=True, color='lightcoral', linestyle='--', label='diff - REF')
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='sqerr', rescale=True, color='cornflowerblue', linestyle='--', label='sqerr - REF')
#
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='diff', rescale=True, color='red', linestyle='-', label='diff - EOF')
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao', reader='post', metric='sqerr', rescale=True, color='blue', linestyle='-', label='sqerr - EOF')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.ylabel('C(t)/C(0) []')
plt.xlabel('t [years]')
plt.title("Cost functions of global mean temperature \n with respect to the equilibrium state [2390-2400]")
# Out:
# 2024-09-18 14:20:29,215 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_diff_1990-2079.nc
# 2024-09-18 14:20:29,221 - INFO - Averaged data found.
# 2024-09-18 14:20:29,229 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_sqerr_1990-2079.nc
# 2024-09-18 14:20:29,233 - INFO - Averaged data found.
# 2024-09-18 14:20:29,234 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao_diff_1990-2079.nc
# 2024-09-18 14:20:29,237 - INFO - Averaged data found.
# 2024-09-18 14:20:29,239 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao_sqerr_1990-2079.nc
# 2024-09-18 14:20:29,243 - INFO - Averaged data found.
# Text(0.5, 1.0, 'Cost functions of global mean temperature \n with respect to the equilibrium state [2390-2400]')

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2130, varlabel='thetao', reader='post', metric='reldiff', rescale=True, color='lightcoral', linestyle='--', label='reldiff - REF')
timeseries(expname='lfr0', startyear=1990, endyear=2130, varlabel='thetao', reader='post', metric='relsqerr', rescale=True, color='cornflowerblue', linestyle='--', label='relsqerr - REF')
#
timeseries(expname='FE01', startyear=1990, endyear=2130, varlabel='thetao', reader='post', metric='reldiff', rescale=True, color='red', linestyle='-', label='reldiff - EOF')
timeseries(expname='FE01', startyear=1990, endyear=2130, varlabel='thetao', reader='post', metric='relsqerr', rescale=True, color='blue', linestyle='-', label='relsqerr - EOF')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.ylabel('C(t)/C(0) []')
plt.xlabel('t [years]')
plt.title("Cost functions of global mean temperature \n with respect to the equilibrium state [2390-2400]")
# Out:
# 2024-09-24 17:08:58,229 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/timeseries_thetao_reldiff_1990-2130.nc
# 2024-09-24 17:08:58,803 - INFO - Averaged data found.
# 2024-09-24 17:08:58,844 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/timeseries_thetao_relsqerr_1990-2130.nc
# 2024-09-24 17:08:58,875 - INFO - Averaged data not found. Creating new file ...
# ...

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='tos', reader='post', rescale=True, color='lightcoral', linestyle='--', label='surface - REF')
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao-pyc', reader='post', rescale=True, color='darkseagreen', linestyle='--', label='pycnoline- REF')
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='sbt', reader='post', rescale=True, color='cornflowerblue', linestyle='--', label='bottom - REF')
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='tos', reader='post', rescale=True, color='red', linestyle='-', label='surface - EOF')
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao-pyc', reader='post', rescale=True, color='green', linestyle='-', label='pycnocline - EOF')
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='sbt', reader='post', rescale=True, color='blue', linestyle='-', label='bottom - EOF')
plt.legend(
    bbox_to_anchor=(0.02, 0.02),  # x, y coordinates for legend placement
    loc='lower left',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.ylabel('temperature [degC]')
plt.xlabel('time [years]')
plt.title('Temperature by ocean layer')
# Out:
# 2024-09-18 14:29:09,838 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_tos_base_1990-2079.nc
# 2024-09-18 14:29:09,843 - INFO - Averaged data found.
# 2024-09-18 14:29:09,851 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao-pyc_base_1990-2079.nc
# 2024-09-18 14:29:09,855 - INFO - Averaged data found.
# 2024-09-18 14:29:09,857 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_sbt_base_1990-2079.nc
# 2024-09-18 14:29:09,860 - INFO - Averaged data found.
# 2024-09-18 14:29:09,862 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_tos_base_1990-2079.nc
# 2024-09-18 14:29:09,866 - INFO - Averaged data found.
# 2024-09-18 14:29:09,868 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao-pyc_base_1990-2079.nc
# 2024-09-18 14:29:09,871 - INFO - Averaged data found.
# 2024-09-18 14:29:09,873 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_sbt_base_1990-2079.nc
# ...

# %%
timeseries_two(expname1='lfr0',expname2='FE01', startyear=1990, endyear=2059, varlabel='thetao', reader='post', metric='diff')
plt.title('temperature distance (diff) between EOF and REF')
# Out:
# 2024-09-09 12:51:01,113 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_base_1990-2059.nc
# 2024-09-09 12:51:01,121 - INFO - Averaged data found.
# 2024-09-09 12:51:01,121 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao_base_1990-2059.nc
# 2024-09-09 12:51:01,161 - INFO - Averaged data found.
# Text(0.5, 1.0, 'temperature distance (diff) between EOF and REF')

# %%
# Create a figure with 3 subplots (one for each layer)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Surface layer
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='tos', reader='post', 
           rescale=False, color='lightcoral', linestyle='--', label='surface - REF', ax=axes[0])
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='tos', reader='post', 
           rescale=False, color='red', linestyle='-', label='surface - EOF', ax=axes[0])
axes[0].legend(loc='upper right')
axes[0].set_title('Surface Layer')

# Pycnocline layer
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='thetao-pyc', reader='post', 
           rescale=False, color='darkseagreen', linestyle='--', label='pycnocline - REF', ax=axes[1])
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='thetao-pyc', reader='post', 
           rescale=False, color='green', linestyle='-', label='pycnocline - EOF', ax=axes[1])
axes[1].legend(loc='upper right')
axes[1].set_title('Pycnocline Layer')

# Bottom layer
timeseries(expname='lfr0', startyear=1990, endyear=2079, varlabel='sbt', reader='post', 
           rescale=False, color='cornflowerblue', linestyle='--', label='bottom - REF', ax=axes[2])
timeseries(expname='FE01', startyear=1990, endyear=2079, varlabel='sbt', reader='post', 
           rescale=False, color='blue', linestyle='-', label='bottom - EOF', ax=axes[2])
axes[2].legend(loc='upper right')
axes[2].set_ylabel('Temperature [degC]')
axes[2].set_xlabel('Time [years]')

# Adjust layout to prevent overlap
plt.tight_layout()

# Set the main title for the figure

fig.suptitle('Temperature by Ocean Layer', fontsize=16, y=1.02)
# Out:
# 2024-09-19 15:17:01,618 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_tos_base_1990-2079.nc
# 2024-09-19 15:17:01,625 - INFO - Averaged data found.
# 2024-09-19 15:17:01,628 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_tos_base_1990-2079.nc
# 2024-09-19 15:17:01,632 - INFO - Averaged data found.
# 2024-09-19 15:17:01,636 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao-pyc_base_1990-2079.nc
# 2024-09-19 15:17:01,640 - INFO - Averaged data found.
# 2024-09-19 15:17:01,643 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao-pyc_base_1990-2079.nc
# 2024-09-19 15:17:01,647 - INFO - Averaged data found.
# 2024-09-19 15:17:01,651 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_sbt_base_1990-2079.nc
# 2024-09-19 15:17:01,655 - INFO - Averaged data found.
# 2024-09-19 15:17:01,658 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_sbt_base_1990-2079.nc
# ...

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2020, varlabel='thetao', reader='post', metric='diff', rescale=True, color='lightcoral', linestyle='--', label='diff - REF')
timeseries(expname='FE01', startyear=1990, endyear=2020, varlabel='thetao', reader='post', metric='diff', rescale=True, color='red', linestyle='-', label='diff - EOF T')
timeseries(expname='FE02', startyear=1990, endyear=2020, varlabel='thetao', reader='post', metric='diff', rescale=True, color='orange', linestyle='-', label='diff - EOF TS')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.ylabel('C(t)/C(0) []')
plt.xlabel('t [years]')
plt.title("Cost functions of global mean temperature \n with respect to the equilibrium state [2390-2400]")
# Out:
# 2024-09-25 08:53:35,264 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/timeseries_thetao_diff_1990-2020.nc
# 2024-09-25 08:53:35,296 - INFO - Averaged data not found. Creating new file ...
# ...

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2020, varlabel='so', reader='post', metric='diff', rescale=True, color='lightcoral', linestyle='--', label='diff - REF')
timeseries(expname='FE01', startyear=1990, endyear=2020, varlabel='so', reader='post', metric='diff', rescale=True, color='red', linestyle='-', label='diff - EOF T')
timeseries(expname='FE02', startyear=1990, endyear=2020, varlabel='so', reader='post', metric='diff', rescale=True, color='orange', linestyle='-', label='diff - EOF TS')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.ylabel('C(t)/C(0) []')
plt.xlabel('t [years]')
plt.title("Cost functions of global mean salinity \n with respect to the equilibrium state [2390-2400]")
# Out:
# 2024-09-25 08:59:11,484 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/timeseries_so_diff_1990-2020.nc
# 2024-09-25 08:59:11,487 - INFO - Averaged data not found. Creating new file ...
# ...

# %%
# FE01, FE02

# Create a figure with 3 subplots (one for each layer)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Surface layer
timeseries(expname='lfr0', startyear=1990, endyear=2020, varlabel='tos', reader='post', 
           rescale=False, color='lightcoral', linestyle='--', label='surface - REF', ax=axes[0])
timeseries(expname='FE01', startyear=1990, endyear=2020, varlabel='tos', reader='post', 
           rescale=False, color='red', linestyle='-', label='surface - EOF-T', ax=axes[0])
timeseries(expname='FE02', startyear=1990, endyear=2020, varlabel='tos', reader='post', 
           rescale=False, color='orange', linestyle='-', label='surface - EOF-TS', ax=axes[0])
axes[0].legend(loc='upper right')
axes[0].set_title('Surface Layer')

# Pycnocline layer
timeseries(expname='lfr0', startyear=1990, endyear=2020, varlabel='thetao-pyc', reader='post', 
           rescale=False, color='darkseagreen', linestyle='--', label='pycnocline - REF', ax=axes[1])
timeseries(expname='FE01', startyear=1990, endyear=2020, varlabel='thetao-pyc', reader='post', 
           rescale=False, color='green', linestyle='-', label='pycnocline - EOF-T', ax=axes[1])
timeseries(expname='FE02', startyear=1990, endyear=2020, varlabel='thetao-pyc', reader='post', 
           rescale=False, color='lime', linestyle='-', label='pycnocline - EOF-TS', ax=axes[1])
axes[1].legend(loc='upper right')
axes[1].set_title('Pycnocline Layer')

# Bottom layer
timeseries(expname='lfr0', startyear=1990, endyear=2020, varlabel='sbt', reader='post', 
           rescale=False, color='cornflowerblue', linestyle='--', label='bottom - REF', ax=axes[2])
timeseries(expname='FE01', startyear=1990, endyear=2020, varlabel='sbt', reader='post', 
           rescale=False, color='blue', linestyle='-', label='bottom - EOF-T', ax=axes[2])
timeseries(expname='FE01', startyear=1990, endyear=2020, varlabel='sbt', reader='post', 
           rescale=False, color='deepskyblue', linestyle='-', label='bottom - EOF-TS', ax=axes[2])
axes[2].legend(loc='upper right')
axes[2].set_ylabel('Temperature [degC]')
axes[2].set_xlabel('Time [years]')

# Adjust layout to prevent overlap
plt.tight_layout()

# Set the main title for the figure
fig.suptitle('Temperature by Ocean Layer', fontsize=16, y=1.02)
# Out:
# 2024-09-25 08:58:13,642 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/timeseries_tos_base_1990-2020.nc
# 2024-09-25 08:58:13,644 - INFO - Averaged data not found. Creating new file ...
# ...

# %%
### LONG TIMESERIES OF CONTROL SIMULATION

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2400, varlabel='thetao', reader='post', metric='base', rescale=True, color='lightcoral', linestyle='--', label='base - REF')
# Out:
# 2024-09-25 09:14:38,524 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/timeseries_thetao_base_1990-2400.nc
# 2024-09-25 09:14:38,777 - INFO - Averaged data not found. Creating new file ...
# 2024-09-25 09:14:47,767 - WARNING - Data available only in the range 1990-2399.
# ...

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2400, varlabel='thetao', reader='post', metric='diff', rescale=True, color='red', linestyle='--', label='diff - REF')
