# %%
import yaml
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from osprey.graphics.timeseries import timeseries, timeseries_two

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2080, varlabel='thetao', reader='post', metric='diff')
timeseries(expname='FE01', startyear=1990, endyear=2080, varlabel='thetao', reader='post', metric='diff')
plt.gca().legend(['REF','EOF'])
# Out:
# 2024-09-13 10:48:33,305 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_diff_1990-2080.nc
# 2024-09-13 10:48:33,369 - INFO - Averaged data not found. Creating new file ...
# ...

# %%
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='tos', color='red', rescaled=True, reader='post')
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='thetao-pyc', color='green', rescaled=True, reader='post')
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='sbt', color='blue', rescaled=True, reader='post')
plt.gca().legend(['surface','pycnocline','bottom'])
plt.ylabel("layer-based temperature")
# Out:
# 2024-09-09 12:50:56,319 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_tos_base_1990-2059.nc
# 2024-09-09 12:50:56,384 - INFO - Averaged data found.
# 2024-09-09 12:50:56,408 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao-pyc_base_1990-2059.nc
# 2024-09-09 12:50:56,494 - INFO - Averaged data found.
# 2024-09-09 12:50:56,499 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_sbt_base_1990-2059.nc
# 2024-09-09 12:50:56,547 - INFO - Averaged data found.
# Text(0, 0.5, 'layer-based temperature')

# %%
timeseries_two(expname1='lfr0',expname2='FE01', startyear=1990, endyear=2059, varlabel='thetao', reader='post', metric='diff')
plt.title('temperature distance (diff) between EOF and REF')
# Out:
# 2024-09-09 12:51:01,113 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_base_1990-2059.nc
# 2024-09-09 12:51:01,121 - INFO - Averaged data found.
# 2024-09-09 12:51:01,121 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/timeseries_thetao_base_1990-2059.nc
# 2024-09-09 12:51:01,161 - INFO - Averaged data found.
# Text(0.5, 1.0, 'temperature distance (diff) between EOF and REF')

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2059, varlabel='tos', reader='post', metric='diff')
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='tos', reader='post', metric='diff')
plt.gca().legend(['REF','EOF'])
# Out:
# 2024-09-09 15:03:22,519 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_tos_diff_1990-2059.nc
# 2024-09-09 15:03:22,527 - INFO - Averaged data not found. Creating new file ...
# ...

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2059, varlabel='sbt', reader='post', metric='diff')
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='sbt', reader='post', metric='diff')
plt.gca().legend(['REF','EOF'])

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2059, varlabel='thetao-pyc', reader='post', metric='diff')
timeseries(expname='FE01', startyear=1990, endyear=2059, varlabel='thetao-pyc', reader='post', metric='diff')
plt.gca().legend(['REF','EOF'])

# %%
timeseries(expname='lfr0', startyear=1990, endyear=2059, varlabel='thetao', reader='post', metric='rdiff')
# Out:
# 2024-09-10 10:29:46,677 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_rdiff_1990-2059.nc
# 2024-09-10 10:29:48,037 - INFO - Averaged data not found. Creating new file ...
# ...
