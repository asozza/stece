# %%
import yaml
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from osprey.graphics.profile import profile

# %%
# 10-year average
profile(expname='lfr0', startyear=2049, endyear=2059, varlabel='thetao', reader='post', replace=False, metric='diff')
profile(expname='FE01', startyear=2049, endyear=2059, varlabel='thetao', reader='post', replace=False, metric='diff')
plt.gca().legend(['REF [2049-2059]','EOF [2049-2059]'])
plt.title('10-year mean vertical profile distance from reference [2390-2400]')
# Out:
# 2024-09-09 12:55:50,848 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/profile_thetao_diff_2049-2059.nc
# 2024-09-09 12:55:50,871 - INFO - Averaged data found.
# 2024-09-09 12:55:50,881 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/profile_thetao_diff_2049-2059.nc
# 2024-09-09 12:55:50,895 - INFO - Averaged data found.
# Text(0.5, 1.0, '10-year mean vertical profile distance from reference [2390-2400]')
