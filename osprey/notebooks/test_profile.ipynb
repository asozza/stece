# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
from osprey.graphics.profile import profile

# %%
profile(expname='lfr0', startyear=2220, endyear=2230, varlabel='thetao', reader='post', replace=True)
# Out:
# 2024-11-25 19:53:24,795 - INFO - Averaged data to be replaced. Creating new file ...
# 2024-11-25 19:53:24,797 - INFO - Data available in the range 2220-2230.
# 2024-11-25 19:53:27,024 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/thetao_lfr0_2220-2230_profile_global_base.nc

# %%
# 10-year average
refinfo = {'expname': 'lgr3', 'startyear': 2340, 'endyear': 2349, 'diagname': 'profile', 'format': 'global'}
profile(expname='lfr0', startyear=2220, endyear=2230, varlabel='thetao', reader='post', replace=True, metric='diff', refinfo=refinfo, color='lightcoral', linestyle='--', label='REF [2340-2349]')
profile(expname='FE01', startyear=2220, endyear=2230, varlabel='thetao', reader='post', replace=True, metric='diff', refinfo=refinfo, color='red', linestyle='-', label='EOF [2070-2079]')
#profile(expname='lfr0', startyear=2040, endyear=2049, varlabel='thetao', reader='post', metric='diff', refinfo=refinfo, color='darkseagreen', linestyle='--', label='REF [2040-2049]')
#profile(expname='FE01', startyear=2040, endyear=2049, varlabel='thetao', reader='post', metric='diff', refinfo=refinfo, color='green', linestyle='-', label='EOF [2040-2049]')
#profile(expname='lfr0', startyear=2010, endyear=2019, varlabel='thetao', reader='post', metric='diff', refinfo=refinfo, color='cornflowerblue', linestyle='--', label='REF [2010-2019]')
#profile(expname='FE01', startyear=2010, endyear=2019, varlabel='thetao', reader='post', metric='diff', refinfo=refinfo, color='blue', linestyle='-', label='EOF [2010-2019]')
#profile(expname='lfr0', startyear=2049, endyear=2079, varlabel='thetao', reader='post', replace=False, metric='diff')
#profile(expname='FE01', startyear=2049, endyear=2079, varlabel='thetao', reader='post', replace=False, metric='diff')
#plt.gca().legend(['REF [2049-2059]','EOF [2049-2059]'])
plt.legend(
    bbox_to_anchor=(0.98, 0.02),  # x, y coordinates for legend placement
    loc='lower right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('10-year mean vertical profile distance from REF [2390-2400]')
# Out:
# 2024-11-25 19:53:31,115 - INFO - Averaged data to be replaced. Creating new file ...
# 2024-11-25 19:53:31,117 - INFO - Data available in the range 2220-2230.
# 2024-11-25 19:53:31,895 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/thetao_lfr0_2220-2230_profile_global_base.nc
# 2024-11-25 19:53:32,344 - INFO - Averaged reference data to be replaced. Creating new file ...
# 2024-11-25 19:53:32,346 - INFO - Data available in the range 2340-2349.
# 2024-11-25 19:53:33,842 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lgr3/post/thetao_lgr3_2340-2349_profile_global_base.nc
# 2024-11-25 19:53:38,512 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/thetao_lfr0_2220-2230_profile_global_diff_lgr3_2340-2349_profile_global.nc
# 2024-11-25 19:53:39,490 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/thetao_lfr0_2220-2230_profile_global_diff_lgr3_2340-2349_profile_global.nc
# 2024-11-25 19:53:39,595 - INFO - Averaged data to be replaced. Creating new file ...
# 2024-11-25 19:53:39,767 - WARNING - Data available only in the range 2220-2229.
# 2024-11-25 19:53:41,192 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/FE01/post/thetao_FE01_2220-2230_profile_global_base.nc
# 2024-11-25 19:53:45,502 - INFO - Averaged reference data to be replaced. Creating new file ...
# 2024-11-25 19:53:45,525 - INFO - Data available in the range 2340-2349.
# 2024-11-25 19:53:46,085 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lgr3/post/thetao_lgr3_2340-2349_profile_global_base.nc
# 2024-11-25 19:53:46,527 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/FE01/post/thetao_FE01_2220-2230_profile_global_diff_lgr3_2340-2349_profile_global.nc
# 2024-11-25 19:53:47,277 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/FE01/post/thetao_FE01_2220-2230_profile_global_diff_lgr3_2340-2349_profile_global.nc
# Text(0.5, 1.0, '10-year mean vertical profile distance from REF [2390-2400]')
