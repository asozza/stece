# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
from osprey.graphics.profile import profile

# %%
profile(expname='lfr0', startyear=2220, endyear=2230, varlabel='thetao', reader='post', replace=True)
# Out:
# 2024-11-28 10:35:36,424 - INFO - Averaged data to be replaced. Creating new file ...
# 2024-11-28 10:35:36,461 - INFO - Data available in the range 2220-2230.
# 2024-11-28 10:35:49,218 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/thetao_lfr0_2220-2230_profile_global_base.nc

# %%
# 10-year average
refinfo = {'expname': 'lgr3', 'startyear': 2340, 'endyear': 2349, 'diagname': 'profile', 'format': 'global'}
profile(expname='lfr0', startyear=2220, endyear=2230, varlabel='thetao', reader='post', replace=False, metric='diff', refinfo=refinfo, color='gray', linestyle='--', label='REF')
profile(expname='FE01', startyear=2220, endyear=2230, varlabel='thetao', reader='post', replace=False, metric='diff', refinfo=refinfo, color='red', linestyle='-', label='EOF-T 10y')
profile(expname='FE02', startyear=2180, endyear=2190, varlabel='thetao', reader='post', replace=False, metric='diff', refinfo=refinfo, color='green', linestyle='-', label='EOF-TS 10y')
profile(expname='FE03', startyear=2090, endyear=2100, varlabel='thetao', reader='post', replace=False, metric='diff', refinfo=refinfo, color='blue', linestyle='-', label='EOF-TS 15y')
#profile(expname='lfr0', startyear=2040, endyear=2049, varlabel='thetao', reader='post', metric='diff', refinfo=refinfo, color='darkseagreen', linestyle='--', label='REF [2040-2049]')
#profile(expname='FE01', startyear=2040, endyear=2049, varlabel='thetao', reader='post', metric='diff', refinfo=refinfo, color='green', linestyle='-', label='EOF [2040-2049]')
#profile(expname='lfr0', startyear=2010, endyear=2019, varlabel='thetao', reader='post', metric='diff', refinfo=refinfo, color='cornflowerblue', linestyle='--', label='REF [2010-2019]')
#profile(expname='FE01', startyear=2010, endyear=2019, varlabel='thetao', reader='post', metric='diff', refinfo=refinfo, color='blue', linestyle='-', label='EOF [2010-2019]')
#profile(expname='lfr0', startyear=2049, endyear=2079, varlabel='thetao', reader='post', replace=False, metric='diff')
#profile(expname='FE01', startyear=2049, endyear=2079, varlabel='thetao', reader='post', replace=False, metric='diff')
#plt.gca().legend(['REF [2049-2059]','EOF [2049-2059]'])
plt.legend(
    bbox_to_anchor=(0.98, 0.02),  # x, y coordinates for legend placement
    loc='lower right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('10-year mean vertical profile distance from REF [2340-2349]')
# Out:
# 2024-11-28 10:40:24,446 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/lfr0/post/thetao_lfr0_2220-2230_profile_global_diff_lgr3_2340-2349_profile_global.nc
# 2024-11-28 10:40:24,548 - INFO - Averaged data found.
# 2024-11-28 10:40:24,582 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/FE01/post/thetao_FE01_2220-2230_profile_global_diff_lgr3_2340-2349_profile_global.nc
# 2024-11-28 10:40:24,594 - INFO - Averaged data found.
# 2024-11-28 10:40:24,596 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/FE02/post/thetao_FE02_2180-2190_profile_global_diff_lgr3_2340-2349_profile_global.nc
# 2024-11-28 10:40:24,600 - INFO - Averaged data found.
# 2024-11-28 10:40:24,601 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/FE03/post/thetao_FE03_2090-2100_profile_global_diff_lgr3_2340-2349_profile_global.nc
# 2024-11-28 10:40:24,604 - INFO - Averaged data found.
# Text(0.5, 1.0, '10-year mean vertical profile distance from REF [2340-2349]')
