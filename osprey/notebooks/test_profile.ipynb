# %%
import yaml
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from osprey.graphics.profile import profile

# %%
# 10-year average
profile(expname='lfr0', startyear=2049, endyear=2059, varlabel='thetao', reader='post', replace=True, metric='diff')
profile(expname='FE01', startyear=2049, endyear=2059, varlabel='thetao', reader='post', replace=True, metric='diff')
plt.gca().legend(['REF','EOF'])
plt.title('profile distance from reference years 2390-2400')
# Out:
# 2024-09-09 10:27:17,225 - INFO - Files to be loaded ['/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2049-2049.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2050-2050.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2051-2051.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2052-2052.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2053-2053.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2054-2054.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2055-2055.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2056-2056.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2057-2057.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2058-2058.nc', '/ec/res4/scratch/itas/ece4/lfr0/output/nemo/lfr0_oce_1m_T_2059-2059.nc']
# 2024-09-09 10:27:17,872 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/field_thetao_base_2390-2400.nc
# ...
