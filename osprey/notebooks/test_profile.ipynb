# %%
import yaml
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from osprey.graphics.profile import profile

# %%
# 10-year average
profile(expname='lfr0', startyear=2070, endyear=2079, varlabel='thetao', reader='post', metric='diff', color='lightcoral', linestyle='--', label='REF [2070-2079]')
profile(expname='FE01', startyear=2070, endyear=2079, varlabel='thetao', reader='post', metric='diff', color='red', linestyle='-', label='EOF [2070-2079]')
profile(expname='lfr0', startyear=2040, endyear=2049, varlabel='thetao', reader='post', metric='diff', color='darkseagreen', linestyle='--', label='REF [2040-2049]')
profile(expname='FE01', startyear=2040, endyear=2049, varlabel='thetao', reader='post', metric='diff', color='green', linestyle='-', label='EOF [2040-2049]')
profile(expname='lfr0', startyear=2010, endyear=2019, varlabel='thetao', reader='post', metric='diff', color='cornflowerblue', linestyle='--', label='REF [2010-2019]')
profile(expname='FE01', startyear=2010, endyear=2019, varlabel='thetao', reader='post', metric='diff', color='blue', linestyle='-', label='EOF [2010-2019]')
#profile(expname='lfr0', startyear=2049, endyear=2079, varlabel='thetao', reader='post', replace=False, metric='diff')
#profile(expname='FE01', startyear=2049, endyear=2079, varlabel='thetao', reader='post', replace=False, metric='diff')
#plt.gca().legend(['REF [2049-2059]','EOF [2049-2059]'])
plt.legend(
    bbox_to_anchor=(0.98, 0.02),  # x, y coordinates for legend placement
    loc='lower right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('10-year mean vertical profile distance from REF [2390-2400]')
# Out:
# 2024-09-19 08:54:00,301 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/profile_thetao_diff_2070-2079.nc
# 2024-09-19 08:54:00,312 - INFO - Averaged data found.
# 2024-09-19 08:54:00,321 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/profile_thetao_diff_2070-2079.nc
# 2024-09-19 08:54:00,324 - INFO - Averaged data found.
# 2024-09-19 08:54:00,326 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/profile_thetao_diff_2040-2049.nc
# 2024-09-19 08:54:00,355 - INFO - Averaged data found.
# 2024-09-19 08:54:00,357 - INFO - File to be loaded /perm/itas/ece4/FE01/nemo/profile_thetao_diff_2040-2049.nc
# 2024-09-19 08:54:00,363 - INFO - Averaged data found.
# 2024-09-19 08:54:00,367 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/profile_thetao_diff_2010-2019.nc
# 2024-09-19 08:54:00,368 - INFO - Averaged data not found. Creating new file ...
# ...
