# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from osprey.actions.post_reader import postreader_averaged 
from osprey.graphics.gregory_plot import gregory_plot

# %%
gregory_plot(expname='lfr0', startyear=1990, endyear=2059, varname1='thetao', varname2='qt_oce', reader='post', replace=False, metric='base')
gregory_plot(expname='FE01', startyear=1990, endyear=2059, varname1='thetao', varname2='qt_oce', reader='post', replace=False, metric='base')
plt.gca().legend(['REF','EOF'])
plt.title('Gregory plot')
# Out:
# 2024-09-09 13:58:29,956 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_thetao_base_1990-2059.nc
# 2024-09-09 13:58:30,028 - INFO - Averaged data found.
# 2024-09-09 13:58:30,029 - INFO - File to be loaded /perm/itas/ece4/lfr0/nemo/timeseries_qt_oce_base_1990-2059.nc
# 2024-09-09 13:58:30,032 - INFO - Averaged data not found. Creating new file ...
# ...
