# %%
import os
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from osprey.actions.reader import reader_nemo

# %%
data = reader_nemo('FE00', 1990, 2021)

# %%
from osprey.graphics.timeseries import timeseries, timeseries_diff, timeseries_diff_mf
from osprey.graphics.profile import profile, profile_diff, profile_diff_two

# %%
timeseries(expname='FE01', startyear=1990, endyear=2020, var='thetao')

# %%
timeseries_diff(expname1='FE00', expname2='lfr0', startyear=1990, endyear=2000, var='thetao')

# %%
profile(expname='FE00', startyear=1990, endyear=2000, var='thetao')

# %%
profile_diff(expname1='FE00', expname2='lfr0', startyear=1990, endyear=2000, var='thetao')

# %%
timeseries(expname='FE00', startyear=1990, endyear=2027, var='thetao', color='blue', rescaled=True, subregion='mixed-layer')
timeseries(expname='FE00', startyear=1990, endyear=2027, var='thetao', color='red', rescaled=True, subregion='pycnocline')
timeseries(expname='FE00', startyear=1990, endyear=2027, var='thetao', color='green', rescaled=True, subregion='abyss')

# %%
timeseries_diff('FE00', 'lfr0', 1990, 2010, 'thetao')

# %%
data = reader_nemo('FE00', 1990, 2021)

# %%
rdata = reader_nemo('lfr0', 1990, 2010)

# %%
#### TEST ON COST FUNCTIONS

# %%
timeseries_diff_mf(expname1='lfr0', startyear1=1990, endyear1=2050, expname2='lfr0', startyear2=2050, endyear2=2060, var='tos') # cost_type='norm'

# %%
timeseries_diff_mf(expname1='lfr0', startyear1=1990, endyear1=2050, expname2='lfr0', startyear2=2040, endyear2=2050, var='tos', cost_type="diff")

# %%
timeseries_diff_mf(expname1='lfr0', startyear1=1990, endyear1=2030, expname2='lfr0', startyear2=2020, endyear2=2030, var='thetao', cost_type="diff")

# %%
profile_diff_two(expname1='lfr0', expname2='lfr0', startyear1=1990, endyear1=1990, startyear2=2030, endyear2=2030, var='thetao', cost_type='diff')
profile_diff_two(expname1='lfr0', expname2='lfr0', startyear1=2000, endyear1=2000, startyear2=2030, endyear2=2030, var='thetao', cost_type='diff')
profile_diff_two(expname1='lfr0', expname2='lfr0', startyear1=2010, endyear1=2010, startyear2=2030, endyear2=2030, var='thetao', cost_type='diff')
plt.gca().legend(['1990','2000','2010'])

# %%
# FITNESS OF THE COST FUNCTIONS ON EOF PROCEDURE (FE00)

# %%
timeseries_diff_mf(expname1='lfr0', startyear1=1990, endyear1=2027, expname2='lfr0', startyear2=2390, endyear2=2400, var='tos', cost_type="diff")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2027, expname2='lfr0', startyear2=2390, endyear2=2400, var='tos', cost_type="diff")

# %%
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', cost_type="diff")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', cost_type="rdiff")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', cost_type="abs")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', cost_type="rel")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', cost_type="var")
plt.gca().legend(['diff','rdiff','abs','rel','var'])
plt.yscale('log')

# %%
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', rescaled=True, cost_type="diff")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', rescaled=True, cost_type="rdiff")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', rescaled=True, cost_type="abs")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', rescaled=True, cost_type="rel")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2020, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', rescaled=True, cost_type="var")
plt.gca().legend(['diff','rdiff','abs','rel','var'])
plt.yscale('log')

# %%
timeseries_diff_mf(expname1='lfr0', startyear1=1990, endyear1=2026, expname2='lfr0', startyear2=2390, endyear2=2400, var='thetao', cost_type="diff")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2026, expname2='lfr0', startyear2=2390, endyear2=2400, var='thetao', cost_type="diff")
plt.title('Reference year window=2390-2400')
plt.gca().legend(['REF','EOF'])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
timeseries_diff_mf(expname1='lfr0', startyear1=1990, endyear1=2026, expname2='lfr0', startyear2=2390, endyear2=2400, var='thetao', cost_type="rvar")
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2026, expname2='lfr0', startyear2=2390, endyear2=2400, var='thetao', cost_type="rvar")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
profile_diff_two(expname1='lfr0', expname2='lfr0', startyear1=2026, endyear1=2026, startyear2=2390, endyear2=2400, var='thetao', cost_type='diff')
profile_diff_two(expname1='FE00', expname2='lfr0', startyear1=2026, endyear1=2026, startyear2=2390, endyear2=2400, var='thetao', cost_type='diff')
plt.title('Current Year = 2026, Reference year window=2390-2400')
plt.gca().legend(['REF','EOF'])

# %%
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2025, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', cost_type="diff", rescaled=True, subregion='mixed-layer')
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2025, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', cost_type="diff", rescaled=True, subregion='pycnocline')
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2025, expname2='lfr0', startyear2=2399, endyear2=2399, var='thetao', cost_type="diff", rescaled=True, subregion='abyss')
plt.title('Reference year window=2390-2400')
plt.gca().legend(['mixed-layer','pycnocline','abyss'])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2026, expname2='lfr0', startyear2=2390, endyear2=2400, var='thetao', cost_type="rel", rescaled=False, subregion='mixed-layer')
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2026, expname2='lfr0', startyear2=2390, endyear2=2400, var='thetao', cost_type="rel", rescaled=False, subregion='pycnocline')
timeseries_diff_mf(expname1='FE00', startyear1=1990, endyear1=2026, expname2='lfr0', startyear2=2390, endyear2=2400, var='thetao', cost_type="rel", rescaled=False, subregion='abyss')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
