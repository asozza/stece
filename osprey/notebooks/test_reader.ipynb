# %%
import os
import numpy as np
from osprey.actions.reader import reader_nemo
from osprey.utils.vardict import vardict
from osprey.graphics.timeseries import timeseries, timeseries_diff
from osprey.graphics.profile import profile, profile_diff
from osprey.means.means import movave, spacemean
from osprey.utils.time import get_decimal_year
import matplotlib.pyplot as plt
import xarray as xr

# %%
timeseries(expname='FE00', startyear=1990, endyear=2027, var='thetao')

# %%
timeseries_diff(expname1='FE00', expname2='lfr0', startyear=1990, endyear=2000, var='thetao')

# %%
profile(expname='FE00', startyear=1990, endyear=2000, var='thetao')

# %%
profile_diff(expname1='FE00', expname2='lfr0', startyear=1990, endyear=2000, var='thetao')

# %%
timeseries(expname='FE00', startyear=1990, endyear=2027, var='thetao', subregion='mixed-layer', cost_value=1, offset=0, color='blue', rescaled='True')
timeseries(expname='FE00', startyear=1990, endyear=2027, var='thetao', subregion='pycnocline', cost_value=1, offset=0, color='red', rescaled='True')
timeseries(expname='FE00', startyear=1990, endyear=2027, var='thetao', subregion='abyss', cost_value=1, offset=0, color='green', rescaled='True')

# %%
timeseries_diff('FE00', 'lfr0', 1990, 2010, 'thetao', subregion, offset, color)

# %%
data = reader_nemo('FE00', 1990, 2021)

# %%
rdata = reader_nemo('lfr0', 1990, 2010)

# %%
tvec = get_decimal_year(data['time'].values)
vec = movave(spacemean(data, 'thetao', '3D'),12)
tt = tvec[6:-6]; vv = vec[6:-6]
plt.plot(tt, vv, 'blue')
#
tvec = get_decimal_year(rdata['time'].values)
vec = movave(spacemean(rdata, 'thetao', '3D'),12)
tt = tvec[6:-6]; vv = vec[6:-6]
plt.plot(tt, vv, 'red')
