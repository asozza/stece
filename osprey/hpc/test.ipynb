# %%
import numpy as np
import matplotlib.pyplot as plt
import osprey.hpc.hpc as hpc

# %%
hpc.multiplot_vs_time('FE01', 0)

# %%
hpc.multiplot_vs_time('lf01', 0)

# %%
hpc.plot_sypd_vs_time('lfr3', 0)
hpc.plot_sypd_vs_time('lfr4', 0)
plt.gca().legend(('lfr3','lfr4'))

# %%
hpc.plot_sypd_vs_nptot(['z008','sr00','z003','alef'], 100)

# %%
#expnames = ['LB01', 'LB02', 'LB03', 'LB04', 'LB05', 'LB06', 'LB07', 'LB10', 'LB11', 'LB12', 'LB13', 'LB14', 'LB15', 'LB16', 'LB21', 'LB22', 'LB23', 'LB24', 'LB25', 'LB26', 'LB31', 'LB32', 'LB33', 'LB34', 'LB35', 'LB36', 'LB37', 'LC32' ]
